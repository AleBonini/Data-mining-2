# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from collections import defaultdict

# %%
from google.colab import files
uploaded = files.upload()
df = uploaded
df = pd.read_csv('AirQualityUCI(1).csv')
class_name = 'weekend'
df.head()
# Out:
#      <input type="file" id="files-5e4f7295-5f28-423a-85ad-fb168e92d032" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5e4f7295-5f28-423a-85ad-fb168e92d032">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving AirQualityUCI(1).csv to AirQualityUCI(1).csv
#         Date      Time  CO(GT)  ...      AH  Unnamed: 15  Unnamed: 16
# 0  3/10/2004  18:00:00     2.6  ...  0.7578          NaN          NaN
# 1  3/10/2004  19:00:00     2.0  ...  0.7255          NaN          NaN
# 2  3/10/2004  20:00:00     2.2  ...  0.7502          NaN          NaN
# 3  3/10/2004  21:00:00     2.2  ...  0.7867          NaN          NaN
# 4  3/10/2004  22:00:00     1.6  ...  0.7888          NaN          NaN
#
# [5 rows x 17 columns]

# %%
df.drop(['Unnamed: 15', 'Unnamed: 16'],axis= 1, inplace = True)

# %%
df.isnull().sum()
# Out:
# Date             114
# Time             114
# CO(GT)           114
# PT08.S1(CO)      114
# NMHC(GT)         114
# C6H6(GT)         114
# PT08.S2(NMHC)    114
# NOx(GT)          114
# PT08.S3(NOx)     114
# NO2(GT)          114
# PT08.S4(NO2)     114
# PT08.S5(O3)      114
# T                114
# RH               114
# AH               114
# dtype: int64

# %%
df.shape
# Out:
# (9471, 15)

# %%
df.dropna(how = 'all',inplace = True)

# %%
df.isnull().sum()
# Out:
# Date             0
# Time             0
# CO(GT)           0
# PT08.S1(CO)      0
# NMHC(GT)         0
# C6H6(GT)         0
# PT08.S2(NMHC)    0
# NOx(GT)          0
# PT08.S3(NOx)     0
# NO2(GT)          0
# PT08.S4(NO2)     0
# PT08.S5(O3)      0
# T                0
# RH               0
# AH               0
# dtype: int64

# %%
b = pd.DataFrame(df.Date)
b['Date'] = pd.to_datetime(b['Date'])

b['day_of_week'] = b['Date'].dt.day_name()

# %%
df['weekday'] = b['day_of_week']

# %%
tf = []
for i in df.weekday:
    if i == 'Sunday' or i == 'Saturday':
        tf.append(1)
    else:
        tf.append(0)

# %%
df['weekend'] = tf

# %%
df.drop(columns=['weekday','AH','NMHC(GT)'],axis = 1,inplace=True)

# %%
df.head()
# Out:
#         Date      Time  CO(GT)  PT08.S1(CO)  ...  PT08.S5(O3)     T    RH  weekend
# 0  3/10/2004  18:00:00     2.6       1360.0  ...       1268.0  13.6  48.9        0
# 1  3/10/2004  19:00:00     2.0       1292.0  ...        972.0  13.3  47.7        0
# 2  3/10/2004  20:00:00     2.2       1402.0  ...       1074.0  11.9  54.0        0
# 3  3/10/2004  21:00:00     2.2       1376.0  ...       1203.0  11.0  60.0        0
# 4  3/10/2004  22:00:00     1.6       1272.0  ...       1110.0  11.2  59.6        0
#
# [5 rows x 14 columns]

# %%
df['PT08_feat'] = ( df['PT08.S2(NMHC)'] + df['PT08.S1(CO)'] + df['PT08.S4(NO2)'] + df['PT08.S5(O3)']) / 4

# %%
df.drop(columns=['PT08.S1(CO)', 'PT08.S2(NMHC)','PT08.S4(NO2)', 'PT08.S5(O3)'],axis=1,inplace=True)

# %%
df.loc[df.PT08_feat < 0, 'PT08_feat'] = df.PT08_feat.mean()
df.loc[df['CO(GT)'] < 0, 'CO(GT)'] = df['CO(GT)'].mean()
df.loc[df['RH'] < 0, 'RH'] = df['RH'].mean()
df.loc[df['C6H6(GT)'] < -50, 'C6H6(GT)'] = df['C6H6(GT)'].mean()
df.loc[df['PT08.S3(NOx)'] < 0, 'PT08.S3(NOx)'] = df['PT08.S3(NOx)'].mean()
df.loc[df['NO2(GT)'] < -50, 'NO2(GT)'] = df['NO2(GT)'].mean()
df.loc[df['T'] < -50, 'T'] = df['T'].mean()

# %%
df.head()
# Out:
#         Date      Time  CO(GT)  C6H6(GT)  ...     T    RH  weekend  PT08_feat
# 0  3/10/2004  18:00:00     2.6      11.9  ...  13.6  48.9        0    1341.50
# 1  3/10/2004  19:00:00     2.0       9.4  ...  13.3  47.7        0    1194.50
# 2  3/10/2004  20:00:00     2.2       9.0  ...  11.9  54.0        0    1242.25
# 3  3/10/2004  21:00:00     2.2       9.2  ...  11.0  60.0        0    1277.75
# 4  3/10/2004  22:00:00     1.6       6.5  ...  11.2  59.6        0    1177.00
#
# [5 rows x 11 columns]

# %%
df.to_csv('air_datasat_time.csv')

# %% [markdown]
# # Time series

# %%
# %pylab inline
from pylab import rcParams
rcParams['figure.figsize'] = 16,4
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df['Datetime'] = pd.to_datetime(df['Date'].apply(str)+' '+df['Time'])

# %%
df.drop(columns=['Date','Time'],axis = 1,inplace=True)

# %%
df.set_index(df.Datetime, inplace = True)

# %%
df.head()
# Out:
#                      CO(GT)  C6H6(GT)  ...  PT08_feat            Datetime
# Datetime                               ...
# 2004-03-10 18:00:00     2.6      11.9  ...    1341.50 2004-03-10 18:00:00
# 2004-03-10 19:00:00     2.0       9.4  ...    1194.50 2004-03-10 19:00:00
# 2004-03-10 20:00:00     2.2       9.0  ...    1242.25 2004-03-10 20:00:00
# 2004-03-10 21:00:00     2.2       9.2  ...    1277.75 2004-03-10 21:00:00
# 2004-03-10 22:00:00     1.6       6.5  ...    1177.00 2004-03-10 22:00:00
#
# [5 rows x 10 columns]

# %%
df.set_index("Datetime").plot()

# %%
ts3 = df['PT08_feat'].loc["2004-03-10" : "2004-04-10"]
ts4 = df['C6H6(GT)'].loc["2004-03-10" : "2004-04-10"]

ts3 = (ts3-ts3.mean())/ts3.std()
ts4 = (ts4 - ts4.mean())/ts4.std()

ts3.plot()
ts4.plot()

# %% [markdown]
# # Visualizzo tutti gli attributi

# %%
ts = df['PT08_feat'].loc["2004-03-10" : "2004-04-10"]
ts1 = df['PT08_feat'].loc["2004-04-10" : "2004-05-10"]
ts2 = df['PT08_feat'].loc["2004-05-10" : "2004-06-10"]
ts3 = df['PT08_feat'].loc["2004-06-10" : "2004-07-10"]
ts4 = df['PT08_feat'].loc["2004-07-10" : "2004-08-10"]
ts5 = df['PT08_feat'].loc["2004-08-10" : "2004-09-10"]
ts6 = df['PT08_feat'].loc["2004-09-10" : "2004-10-10"]
ts7 = df['PT08_feat'].loc["2004-10-10" : "2004-11-10"]
ts8 = df['PT08_feat'].loc["2004-11-10" : "2004-12-10"]
ts9 = df['PT08_feat'].loc["2004-12-10" : "2005-01-10"]
ts10 = df['PT08_feat'].loc["2005-01-10" : "2005-02-10"]
ts11 = df['PT08_feat'].loc["2005-02-10" : "2005-03-10"]
ts12 = df['PT08_feat'].loc["2005-03-10" : "2005-04-10"]

ts.plot()
ts1.plot()
ts2.plot()
ts3.plot()
ts4.plot()
ts5.plot()
ts6.plot()
ts7.plot()
ts8.plot()
ts9.plot()
ts10.plot()
ts11.plot()
ts12.plot()

# %%
ts = df['PT08.S3(NOx)'].loc["2004-03-10" : "2004-04-10"]
ts1 = df['PT08.S3(NOx)'].loc["2004-04-10" : "2004-05-10"]
ts2 = df['PT08.S3(NOx)'].loc["2004-05-10" : "2004-06-10"]
ts3 = df['PT08.S3(NOx)'].loc["2004-06-10" : "2004-07-10"]
ts4 = df['PT08.S3(NOx)'].loc["2004-07-10" : "2004-08-10"]
ts5 = df['PT08.S3(NOx)'].loc["2004-08-10" : "2004-09-10"]
ts6 = df['PT08.S3(NOx)'].loc["2004-09-10" : "2004-10-10"]
ts7 = df['PT08.S3(NOx)'].loc["2004-10-10" : "2004-11-10"]
ts8 = df['PT08.S3(NOx)'].loc["2004-11-10" : "2004-12-10"]
ts9 = df['PT08.S3(NOx)'].loc["2004-12-10" : "2005-01-10"]
ts10 = df['PT08.S3(NOx)'].loc["2005-01-10" : "2005-02-10"]
ts11 = df['PT08.S3(NOx)'].loc["2005-02-10" : "2005-03-10"]
ts12 = df['PT08.S3(NOx)'].loc["2005-03-10" : "2005-04-10"]

ts.plot()
ts1.plot()
ts2.plot()
ts3.plot()
ts4.plot()
ts5.plot()
ts6.plot()
ts7.plot()
ts8.plot()
ts9.plot()
ts10.plot()
ts11.plot()
ts12.plot()

# %%
ts = df['NO2(GT)'].loc["2004-03-10" : "2004-04-10"]
ts1 = df['NO2(GT)'].loc["2004-04-10" : "2004-05-10"]
ts2 = df['NO2(GT)'].loc["2004-05-10" : "2004-06-10"]
ts3 = df['NO2(GT)'].loc["2004-06-10" : "2004-07-10"]
ts4 = df['NO2(GT)'].loc["2004-07-10" : "2004-08-10"]
ts5 = df['NO2(GT)'].loc["2004-08-10" : "2004-09-10"]
ts6 = df['NO2(GT)'].loc["2004-09-10" : "2004-10-10"]
ts7 = df['NO2(GT)'].loc["2004-10-10" : "2004-11-10"]
ts8 = df['NO2(GT)'].loc["2004-11-10" : "2004-12-10"]
ts9 = df['NO2(GT)'].loc["2004-12-10" : "2005-01-10"]
ts10 = df['NO2(GT)'].loc["2005-01-10" : "2005-02-10"]
ts11 = df['NO2(GT)'].loc["2005-02-10" : "2005-03-10"]
ts12 = df['NO2(GT)'].loc["2005-03-10" : "2005-04-10"]

ts.plot()
ts1.plot()
ts2.plot()
ts3.plot()
ts4.plot()
ts5.plot()
ts6.plot()
ts7.plot()
ts8.plot()
ts9.plot()
ts10.plot()
ts11.plot()
ts12.plot()

# %%
ts = df['NOx(GT)'].loc["2004-03-10" : "2004-04-10"]
ts1 = df['NOx(GT)'].loc["2004-04-10" : "2004-05-10"]
ts2 = df['NOx(GT)'].loc["2004-05-10" : "2004-06-10"]
ts3 = df['NOx(GT)'].loc["2004-06-10" : "2004-07-10"]
ts4 = df['NOx(GT)'].loc["2004-07-10" : "2004-08-10"]
ts5 = df['NOx(GT)'].loc["2004-08-10" : "2004-09-10"]
ts6 = df['NOx(GT)'].loc["2004-09-10" : "2004-10-10"]
ts7 = df['NOx(GT)'].loc["2004-10-10" : "2004-11-10"]
ts8 = df['NOx(GT)'].loc["2004-11-10" : "2004-12-10"]
ts9 = df['NOx(GT)'].loc["2004-12-10" : "2005-01-10"]
ts10 = df['NOx(GT)'].loc["2005-01-10" : "2005-02-10"]
ts11 = df['NOx(GT)'].loc["2005-02-10" : "2005-03-10"]
ts12 = df['NOx(GT)'].loc["2005-03-10" : "2005-04-10"]

ts.plot()
ts1.plot()
ts2.plot()
ts3.plot()
ts4.plot()
ts5.plot()
ts6.plot()
ts7.plot()
ts8.plot()
ts9.plot()
ts10.plot()
ts11.plot()
ts12.plot()

# %%
ts = df['RH'].loc["2004-03-10" : "2004-04-10"]
ts1 = df['RH'].loc["2004-04-10" : "2004-05-10"]
ts2 = df['RH'].loc["2004-05-10" : "2004-06-10"]
ts3 = df['RH'].loc["2004-06-10" : "2004-07-10"]
ts4 = df['RH'].loc["2004-07-10" : "2004-08-10"]
ts5 = df['RH'].loc["2004-08-10" : "2004-09-10"]
ts6 = df['RH'].loc["2004-09-10" : "2004-10-10"]
ts7 = df['RH'].loc["2004-10-10" : "2004-11-10"]
ts8 = df['RH'].loc["2004-11-10" : "2004-12-10"]
ts9 = df['RH'].loc["2004-12-10" : "2005-01-10"]
ts10 = df['RH'].loc["2005-01-10" : "2005-02-10"]
ts11 = df['RH'].loc["2005-02-10" : "2005-03-10"]
ts12 = df['RH'].loc["2005-03-10" : "2005-04-10"]

ts.plot()
ts1.plot()
ts2.plot()
ts3.plot()
ts4.plot()
ts5.plot()
ts6.plot()
ts7.plot()
ts8.plot()
ts9.plot()
ts10.plot()
ts11.plot()
ts12.plot()

# %%
ts = df['T'].loc["2004-03-10" : "2004-04-10"]
ts1 = df['T'].loc["2004-04-10" : "2004-05-10"]
ts2 = df['T'].loc["2004-05-10" : "2004-06-10"]
ts3 = df['T'].loc["2004-06-10" : "2004-07-10"]
ts4 = df['T'].loc["2004-07-10" : "2004-08-10"]
ts5 = df['T'].loc["2004-08-10" : "2004-09-10"]
ts6 = df['T'].loc["2004-09-10" : "2004-10-10"]
ts7 = df['T'].loc["2004-10-10" : "2004-11-10"]
ts8 = df['T'].loc["2004-11-10" : "2004-12-10"]
ts9 = df['T'].loc["2004-12-10" : "2005-01-10"]
ts10 = df['T'].loc["2005-01-10" : "2005-02-10"]
ts11 = df['T'].loc["2005-02-10" : "2005-03-10"]
ts12 = df['T'].loc["2005-03-10" : "2005-04-10"]

ts.plot()
ts1.plot()
ts2.plot()
ts3.plot()
ts4.plot()
ts5.plot()
ts6.plot()
ts7.plot()
ts8.plot()
ts9.plot()
ts10.plot()
ts11.plot()
ts12.plot()

# %%
ts = df['CO(GT)'].loc["2004-03-10" : "2004-04-10"]
ts1 = df['CO(GT)'].loc["2004-04-10" : "2004-05-10"]
ts2 = df['CO(GT)'].loc["2004-05-10" : "2004-06-10"]
ts3 = df['CO(GT)'].loc["2004-06-10" : "2004-07-10"]
ts4 = df['CO(GT)'].loc["2004-07-10" : "2004-08-10"]
ts5 = df['CO(GT)'].loc["2004-08-10" : "2004-09-10"]
ts6 = df['CO(GT)'].loc["2004-09-10" : "2004-10-10"]
ts7 = df['CO(GT)'].loc["2004-10-10" : "2004-11-10"]
ts8 = df['CO(GT)'].loc["2004-11-10" : "2004-12-10"]
ts9 = df['CO(GT)'].loc["2004-12-10" : "2005-01-10"]
ts10 = df['CO(GT)'].loc["2005-01-10" : "2005-02-10"]
ts11 = df['CO(GT)'].loc["2005-02-10" : "2005-03-10"]
ts12 = df['CO(GT)'].loc["2005-03-10" : "2005-04-10"]

ts.plot()
ts1.plot()
ts2.plot()
ts3.plot()
ts4.plot()
ts5.plot()
ts6.plot()
ts7.plot()
ts8.plot()
ts9.plot()
ts10.plot()
ts11.plot()
ts12.plot()

# %% [markdown]
# # Divido per mesi

# %%
ts = df['C6H6(GT)'].loc["2004-03-10" : "2004-04-10"]
ts1 = df['C6H6(GT)'].loc["2004-04-10" : "2004-05-10"]
ts2 = df['C6H6(GT)'].loc["2004-05-10" : "2004-06-10"]
ts3 = df['C6H6(GT)'].loc["2004-06-10" : "2004-07-10"]
ts4 = df['C6H6(GT)'].loc["2004-07-10" : "2004-08-10"]
ts5 = df['C6H6(GT)'].loc["2004-08-10" : "2004-09-10"]
ts6 = df['C6H6(GT)'].loc["2004-09-10" : "2004-10-10"]
ts7 = df['C6H6(GT)'].loc["2004-10-10" : "2004-11-10"]
ts8 = df['C6H6(GT)'].loc["2004-11-10" : "2004-12-10"]
ts9 = df['C6H6(GT)'].loc["2004-12-10" : "2005-01-10"]
ts10 = df['C6H6(GT)'].loc["2005-01-10" : "2005-02-10"]
ts11 = df['C6H6(GT)'].loc["2005-02-10" : "2005-03-10"]
ts12 = df['C6H6(GT)'].loc["2005-03-10" : "2005-04-10"]

ts.plot()
ts1.plot()
ts2.plot()
ts3.plot()
ts4.plot()
ts5.plot()
ts6.plot()
ts7.plot()
ts8.plot()
ts9.plot()
ts10.plot()
ts11.plot()
ts12.plot()

# %%
plt.plot(ts1)
plt.plot(ts2)
plt.show()

# %%
df_marzo1 = pd.DataFrame(data = {'marzo1':ts})
df_aprile = pd.DataFrame(data = {'aprile':ts1})
df_maggio = pd.DataFrame(data = {'maggio':ts2})
df_giugno = pd.DataFrame(data = {'giugno':ts3})
df_luglio = pd.DataFrame(data = {'luglio':ts4})
df_agosto = pd.DataFrame(data = {'agosto':ts5})
df_settembre = pd.DataFrame(data = {'settembre':ts6})
df_ottobre = pd.DataFrame(data = {'ottobre':ts7})
df_novembre = pd.DataFrame(data = {'novembre':ts8})
df_dicembre = pd.DataFrame(data = {'dicembre':ts9})
df_gennaio = pd.DataFrame(data = {'gennaio':ts10})
df_febbraio = pd.DataFrame(data = {'febbraio':ts11})
df_marzo2 = pd.DataFrame(data = {'marzo2':ts12})


df_marzo1.reset_index(inplace= True)
df_aprile.reset_index(inplace= True)
df_maggio.reset_index(inplace= True)
df_giugno.reset_index(inplace= True)
df_luglio.reset_index(inplace= True)
df_agosto.reset_index(inplace= True)
df_settembre.reset_index(inplace= True)
df_ottobre.reset_index(inplace= True)
df_novembre.reset_index(inplace= True)
df_dicembre.reset_index(inplace= True)
df_gennaio.reset_index(inplace= True)
df_febbraio.reset_index(inplace= True)
df_marzo2.reset_index(inplace= True)

ts_marzo1 = pd.Series(df_marzo1.marzo1)
ts_aprile = pd.Series(df_aprile.aprile)
ts_maggio = pd.Series(df_maggio.maggio)
ts_giugno = pd.Series(df_giugno.giugno)
ts_luglio = pd.Series(df_luglio.luglio)
ts_agosto = pd.Series(df_agosto.agosto)
ts_settembre = pd.Series(df_settembre.settembre)
ts_ottobre = pd.Series(df_ottobre.ottobre)
ts_novembre = pd.Series(df_novembre.novembre)
ts_dicembre = pd.Series(df_dicembre.dicembre)
ts_gennaio = pd.Series(df_gennaio.gennaio)
ts_febbraio = pd.Series(df_febbraio.febbraio)
ts_marzo2 = pd.Series(df_marzo2.marzo2)

# %% [markdown]
# # Divido per stagioni

# %%
ts = df['C6H6(GT)'].loc["2004-03-21" : "2004-06-20"]
ts1 = df['C6H6(GT)'].loc["2004-06-21" : "2004-09-20"]
ts2 = df['C6H6(GT)'].loc["2004-09-21" : "2004-12-20"]
ts3 = df['C6H6(GT)'].loc["2004-12-20" : "2005-03-20"]


ts.plot()
ts1.plot()
ts2.plot()
ts3.plot()

# %%
df_primavera = pd.DataFrame(data = {'primavera':ts})
df_estate = pd.DataFrame(data = {'estate':ts1})
df_autunno = pd.DataFrame(data = {'autunno':ts2})
df_inverno = pd.DataFrame(data = {'inverno':ts3})


df_primavera.reset_index(inplace= True)
df_estate.reset_index(inplace= True)
df_inverno.reset_index(inplace= True)
df_autunno.reset_index(inplace= True)


ts_primavera = pd.Series(df_primavera.primavera)
ts_estate = pd.Series(df_estate.estate)
ts_autunno = pd.Series(df_autunno.autunno)
ts_inverno = pd.Series(df_inverno.inverno)

# %% [markdown]
# # Plotting two months

# %%
plt.plot(ts_gennaio)
plt.plot(ts_febbraio)
plt.show()

# %%
plt.plot(ts_inverno)
plt.plot(ts_estate)
plt.show()

# %% [markdown]
# # Transformations

# %% [markdown]
# ### Transformation I: Offset Translation

# %%
plt.plot(ts_gennaio - ts_gennaio.mean())
plt.plot(ts_febbraio - ts_febbraio.mean())
plt.show()

# %% [markdown]
# # Transformation II: Amplitude Scaling

# %%
plt.plot((ts_gennaio - ts_gennaio.mean())/ts_gennaio.std())
plt.plot((ts_febbraio - ts_febbraio.mean())/ts_febbraio.std())
plt.show()

# %%
# !python -m pip install tslearn
# Out:
# ...
#      |████████████████████████████████| 778kB 3.6MB/s
# ...

# %%
from tslearn.preprocessing import TimeSeriesScalerMeanVariance

# %%
scaler = TimeSeriesScalerMeanVariance(mu=0., std=1,)  # Rescale time series
ts_gennaio_scaled = scaler.fit_transform(ts_gennaio).flatten()
ts_febbraio_scaled = scaler.fit_transform(ts_febbraio).flatten()

plt.plot(ts_gennaio_scaled)
plt.plot(ts_febbraio_scaled)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-163-4cde8974724b> in <module>()
#       1 scaler = TimeSeriesScalerMeanVariance(mu=0., std=1)  # Rescale time series
# ----> 2 ts_gennaio_scaled = scaler.fit_transform(ts_gennaio).flatten()
#       3 ts_febbraio_scaled = scaler.fit_transform(ts_febbraio).flatten()
#       4
#       5 plt.plot(ts_gennaio_scaled)
#
# /usr/local/lib/python3.6/dist-packages/tslearn/preprocessing.py in fit_transform(self, X, y, **kwargs)
#     272             Resampled time series dataset.
#     273         """
# --> 274         return self.fit(X).transform(X)
#     275
#     276     def transform(self, X, y=None, **kwargs):
#
# /usr/local/lib/python3.6/dist-packages/tslearn/preprocessing.py in fit(self, X, y, **kwargs)
#     254         self
#     255         """
# ...

# %% [markdown]
# ## Transformation IV: Noise (smoothing)

# %%
w = 10
plt.plot(((ts_gennaio - ts_gennaio.mean())/ts_gennaio.std()).rolling(window=w).mean())
plt.plot(((ts_febbraio - ts_febbraio.mean())/ts_febbraio.std()).rolling(window=w).mean())
plt.show()

# %% [markdown]
# ## Transformation III: Trend removal

# %%
plt.plot(ts_gennaio)
plt.plot(ts_gennaio.rolling(window=12).mean())
plt.show()

# %%
ts_gennaio_shift = ts_gennaio - ts_gennaio.rolling(window=12).mean()
plt.plot(ts_gennaio_shift)
plt.show()
