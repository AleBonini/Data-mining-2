# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from collections import defaultdict
import numpy as np
from datetime import datetime
import scipy.stats as stats
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\Users\pasqu\Anaconda3\lib\site-packages\IPython\core\magics\pylab.py:160: UserWarning: pylab import has clobbered these variables: ['datetime']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %% [markdown]
# # Data preparation

# %%
df = pd.read_csv("3df_uniti.csv")

# %%
df.drop("Unnamed: 0", axis = 1, inplace = True)
df.head()
# Out:
#                   date  Temperature  Humidity       Light         CO2  \
# 0  2015-02-02 14:19:00      23.7000    26.272  585.200000  749.200000
# 1  2015-02-02 14:19:59      23.7180    26.290  578.400000  760.400000
# 2  2015-02-02 14:21:00      23.7300    26.230  572.666667  769.666667
# 3  2015-02-02 14:22:00      23.7225    26.125  493.750000  774.750000
# 4  2015-02-02 14:23:00      23.7540    26.200  488.600000  779.000000
#
#    HumidityRatio  Occupancy
# 0       0.004764          1
# 1       0.004773          1
# 2       0.004765          1
# 3       0.004744          1
# 4       0.004767          1

# %%
df['date']= pd.to_datetime(df['date']) 
df.set_index('date')
# Out:
#                      Temperature  Humidity       Light         CO2  \
# date
# 2015-02-02 14:19:00      23.7000   26.2720  585.200000  749.200000
# 2015-02-02 14:19:59      23.7180   26.2900  578.400000  760.400000
# 2015-02-02 14:21:00      23.7300   26.2300  572.666667  769.666667
# 2015-02-02 14:22:00      23.7225   26.1250  493.750000  774.750000
# 2015-02-02 14:23:00      23.7540   26.2000  488.600000  779.000000
# ...                          ...       ...         ...         ...
# 2015-02-10 09:29:00      21.0500   36.0975  433.000000  787.250000
# 2015-02-10 09:29:59      21.0500   35.9950  433.000000  789.500000
# 2015-02-10 09:30:59      21.1000   36.0950  433.000000  798.500000
# 2015-02-10 09:32:00      21.1000   36.2600  433.000000  820.333333
# 2015-02-10 09:33:00      21.1000   36.2000  447.000000  821.000000
#
#                      HumidityRatio  Occupancy
# date
# 2015-02-02 14:19:00       0.004764          1
# 2015-02-02 14:19:59       0.004773          1
# ...

# %%
# find the transpose 
df.transpose()

# %%
#devo dividere una ts in ore e analizzarla (l'unico senso che sembra esserci)


dates = pd.to_datetime(df['date'], infer_datetime_format=True)
df['day'] = dates.dt.day
df['hour'] = dates.dt.hour

# %%
dates.dt.hour.value_counts()
# Out:
# 7     915
# 1     915
# 19    915
# 4     915
# 22    915
# 21    900
# 18    900
# 3     900
# 6     900
# 0     900
# 23    885
# 8     885
# 5     885
# 20    885
# 2     885
# 16    854
# 15    840
# 17    835
# 9     834
# 10    776
# 14    761
# 13    732
# 12    720
# 11    708
# Name: date, dtype: int64

# %%
h0 = df[df.hour==0]
h1 = df[df.hour==1]
h2 = df[df.hour==2]
h3 = df[df.hour==3]
h4 = df[df.hour==4]
h5 = df[df.hour==5]
h6 = df[df.hour==6]
h7 = df[df.hour==7]
h8 = df[df.hour==8]
h9 = df[df.hour==9]
h10 = df[df.hour==10]
h11 = df[df.hour==11]
h12 = df[df.hour==12]
h13 = df[df.hour==13]
h14 = df[df.hour==14]
h15 = df[df.hour==15]
h16 = df[df.hour==16]
h17 = df[df.hour==17]
h18 = df[df.hour==18]
h19 = df[df.hour==19]
h20 = df[df.hour==20]
h21 = df[df.hour==21]
h22 = df[df.hour==22]
h23 = df[df.hour==23]

# %%
ts1 = pd.Series(h1['CO2'])
plt.plot(ts1)
plt.show()

# %%
ts2 = pd.Series(h2['CO2'])
plt.plot(ts2)
plt.show()

# %%
ts3 = pd.Series(h3['CO2'])
plt.plot(ts3)
plt.show()

# %%
ts4 = pd.Series(h4['CO2'])
plt.plot(ts4)
plt.show()

# %%
ts5 = pd.Series(h5['CO2'])
plt.plot(ts5)
plt.show()

# %%
ts6 = pd.Series(h6['CO2'])
plt.plot(ts6)
plt.show()

# %%
ts7 = pd.Series(h7['CO2'])
plt.plot(ts7)
plt.show()

# %%
ts8 = pd.Series(h8['CO2'])
plt.plot(ts8)
plt.show()

# %%
ts9 = pd.Series(h9['CO2'])
plt.plot(ts9)
plt.show()

# %%
ts10 = pd.Series(h10['CO2'])
plt.plot(ts10)
plt.show()

# %%
ts11 = pd.Series(h11['CO2'])
plt.plot(ts11)
plt.show()

# %%
ts12 = pd.Series(h12['CO2'])
plt.plot(ts12)
plt.show()

# %%
ts13 = pd.Series(h13['CO2'])
plt.plot(ts13)
plt.show()

# %%
ts14 = pd.Series(h14['CO2'])
plt.plot(ts14)
plt.show()

# %%
ts15 = pd.Series(h15['CO2'])
plt.plot(ts15)
plt.show()

# %%
ts16 = pd.Series(h16['CO2'])
plt.plot(ts16)
plt.show()

# %%
ts17 = pd.Series(h17['CO2'])
plt.plot(ts17)
plt.show()

# %%
ts18 = pd.Series(h18['CO2'])
plt.plot(ts18)
plt.show()

# %%
ts19 = pd.Series(h19['CO2'])
plt.plot(ts19)
plt.show()

# %%
ts20 = pd.Series(h20['CO2'])
plt.plot(ts20)
plt.show()

# %%
ts21 = pd.Series(h21['CO2'])
plt.plot(ts21)
plt.show()

# %%
ts22 = pd.Series(h22['CO2'])
plt.plot(ts22)
plt.show()

# %%
ts23 = pd.Series(h23['CO2'])
plt.plot(ts23)
plt.show()

# %%
co2 = [ts1, ts2, ts3, ts4, ts5, ts6, ts7, ts8, ts9, ts10, ts11, ts12, ts13, ts14, ts15, ts16, ts17, ts18, ts19, ts21, ts22, ts23]

# %% [markdown]
# # Feature Extraction

# %%
def calculate_features(values):
    features = {
        'avg': np.mean(values),
        'std': np.std(values),
        'var': np.var(values),
        'med': np.median(values),
        '10p': np.percentile(values, 10),
        '25p': np.percentile(values, 25),
        '50p': np.percentile(values, 50),
        '75p': np.percentile(values, 75),
        '90p': np.percentile(values, 90),
        'iqr': np.percentile(values, 75) - np.percentile(values, 25),
        'cov': 1.0 * np.mean(values) / np.std(values),
        'skw': stats.skew(values),
        'kur': stats.kurtosis(values)
    }

    return features

# %%
feat = []

for i in co2:
    features = calculate_features(i)
    feat.append(features)

# %%
feat
# Out:
# [{'avg': 586.5347358834244,
#   'std': 255.0975994993801,
#   'var': 65074.785270346125,
#   'med': 502.5,
#   '10p': 438.0,
#   '25p': 444.4166666666665,
#   '50p': 502.5,
#   '75p': 574.5,
#   '90p': 843.5333333333333,
#   'iqr': 130.08333333333348,
#   'cov': 2.2992561946269894,
#   'skw': 2.7487932268048048,
#   'kur': 7.782409197728176},
#  {'avg': 574.2824105461393,
#   'std': 213.83003538642697,
#   'var': 45723.284033360615,
#   'med': 494.0,
#   '10p': 436.0,
#   '25p': 441.0,
#   '50p': 494.0,
#   '75p': 576.333333333333,
#   '90p': 858.0,
#   'iqr': 135.33333333333303,
#   'cov': 2.685695718603395,
#   'skw': 2.159018307011207,
#   'kur': 3.9100599647616674},
#  {'avg': 582.7603412698411,
#   'std': 234.30379511253707,
#   'var': 54898.26840413775,
#   'med': 480.875,
#   '10p': 434.5,
#   '25p': 440.1875,
#   '50p': 480.875,
#   '75p': 581.625,
#   '90p': 863.0,
#   'iqr': 141.4375,
#   'cov': 2.487199752739553,
#   'skw': 2.25349049807459,
# ...

# %% [markdown]
# # Compression-based distances

# %%
#cdm è un algoritmo utilizzato per estrarre features dalle time series. I risultati sono 1.00xx per tutte le ts, indip lunghezza
#ci ripasso se serve altrimenti fanculo

import zlib
import string

# %%
def CDM(x, y):
    return len(zlib.compress(x + y)) / (len(zlib.compress(x)) + len(zlib.compress(y)))

# %%
ts_str= (' '.join([str(v) for v in ts])).encode('utf-8')
ts_str
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-c427dea1ecd3> in <module>
# ----> 1 ts_str= (' '.join([str(v) for v in ts])).encode('utf-8')
#       2 ts_str
#
# NameError: name 'ts' is not defined

# %%
ts1_str = (' '.join([str(v) for v in ts1])).encode('utf-8')
ts1_str
# Out:
# b'453.2 447.6 447.666666666667 448.0 451.0 451.0 451.0 449.75 453.0 453.5 452.333333333333 452.0 450.666666666667 449.5 449.75 449.0 451.333333333333 449.0 448.0 443.25 446.5 448.75 451.0 451.5 455.0 451.6 452.666666666667 448.2 445.75 446.666666666667 446.333333333333 444.75 444.5 446.0 443.333333333333 447.0 446.0 445.25 442.0 443.0 443.0 446.333333333333 449.0 445.25 441.25 441.75 441.5 445.0 446.0 442.5 445.0 443.5 443.0 444.333333333333 443.666666666667 443.4 447.0 446.25 445.6 448.5 443.666666666667 529.75 528.75 528.25 526.0 526.5 529.333333333333 528.25 526.8 525.5 524.666666666667 523.0 526.0 523.25 524.333333333333 521.5 518.6 520.75 527.666666666667 526.0 519.6 518.333333333333 520.5 521.75 523.0 520.333333333333 519.0 516.25 518.6 519.333333333333 515.333333333333 516.4 519.5 522.25 514.75 513.75 515.0 519.0 518.8 517.333333333333 509.75 513.6 511.0 512.4 515.5 511.8 511.666666666667 509.75 513.0 508.5 510.0 509.666666666667 508.5 511.25 513.333333333333 509.5 509.0 509.0
# ...

# %%
print("len(ts1_str + ts2_str): ", len(ts_str + ts1_str))
print("len(compress(ts1_str+ts2_str)): ", len(zlib.compress(ts_str+ts1_str)))
print("len(compress(ts1_str)): ", len(zlib.compress(ts_str)))
print("len(compress(ts2_str)): ", len(zlib.compress(ts1_str)))
print("CDM = ", CDM(ts_str, ts1_str))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-c35f6344021c> in <module>
# ----> 1 print("len(ts1_str + ts2_str): ", len(ts_str + ts1_str))
#       2 print("len(compress(ts1_str+ts2_str)): ", len(zlib.compress(ts_str+ts1_str)))
#       3 print("len(compress(ts1_str)): ", len(zlib.compress(ts_str)))
#       4 print("len(compress(ts2_str)): ", len(zlib.compress(ts1_str)))
#       5 print("CDM = ", CDM(ts_str, ts1_str))
#
# NameError: name 'ts_str' is not defined

# %%
print("len(ts1_str + ts2_str): ", len(ts_str + ts1_str))
print("len(compress(ts1_str+ts2_str)): ", len(zlib.compress(ts_str+ts1_str)))
print("len(compress(ts1_str)): ", len(zlib.compress(ts_str)))
print("len(compress(ts2_str)): ", len(zlib.compress(ts1_str)))
print("CDM = ", CDM(ts_str, ts1_str))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-c35f6344021c> in <module>
# ----> 1 print("len(ts1_str + ts2_str): ", len(ts_str + ts1_str))
#       2 print("len(compress(ts1_str+ts2_str)): ", len(zlib.compress(ts_str+ts1_str)))
#       3 print("len(compress(ts1_str)): ", len(zlib.compress(ts_str)))
#       4 print("len(compress(ts2_str)): ", len(zlib.compress(ts1_str)))
#       5 print("CDM = ", CDM(ts_str, ts1_str))
#
# NameError: name 'ts_str' is not defined

# %% [markdown]
# # Time Series Approximation

# %%
from tslearn.piecewise import PiecewiseAggregateApproximation
from tslearn.piecewise import SymbolicAggregateApproximation
from tslearn.piecewise import OneD_SymbolicAggregateApproximation
from tslearn.preprocessing import TimeSeriesScalerMeanVariance

# %%
scaler = TimeSeriesScalerMeanVariance(mu=0., std=1.)  # Rescale time series

# %%
ts1 = scaler.fit_transform(ts1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-2cab5980bc30> in <module>
#       2 df.transpose()
#       3
# ----> 4 ts1 = scaler.fit_transform(ts1)
#
# ~\Anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     569         if y is None:
#     570             # fit method of arity 1 (unsupervised transformation)
# --> 571             return self.fit(X, **fit_params).transform(X)
#     572         else:
#     573             # fit method of arity 2 (supervised transformation)
#
# ~\Anaconda3\lib\site-packages\tslearn\preprocessing.py in transform(self, X, **kwargs)
#     246             Rescaled time series dataset
#     247         """
# --> 248         X_ = to_time_series_dataset(X)
#     249         mean_t = numpy.nanmean(X_, axis=1)[:, numpy.newaxis, :]
# ...

# %%
# PAA transform (and inverse transform) of the data
n_paa_segments = 10
paa = PiecewiseAggregateApproximation(n_segments=n_paa_segments)
ts_paa = paa.fit_transform(ts)
paa_dataset_inv = paa.inverse_transform(ts_paa)

# SAX transform
n_sax_symbols = 8
sax = SymbolicAggregateApproximation(n_segments=n_paa_segments, alphabet_size_avg=n_sax_symbols)
ts_sax = sax.fit_transform(ts)
sax_dataset_inv = sax.inverse_transform(ts_sax)

# 1d-SAX transform
n_sax_symbols_avg = 8
n_sax_symbols_slope = 4
one_d_sax = OneD_SymbolicAggregateApproximation(
    n_segments=n_paa_segments,
    alphabet_size_avg=n_sax_symbols_avg,
    alphabet_size_slope=n_sax_symbols_slope)

ts_sax1d = one_d_sax.fit_transform(ts)
one_d_sax_dataset_inv = one_d_sax.inverse_transform(ts_sax1d)

plt.figure()
plt.subplot(2, 2, 1)  # First, raw time series
plt.plot(ts[0].ravel(), "b-")
plt.title("Raw time series")

plt.subplot(2, 2, 2)  # Second, PAA
plt.plot(ts[0].ravel(), "b-", alpha=0.4)
plt.plot(paa_dataset_inv[0].ravel(), "b-")
plt.title("PAA")

plt.subplot(2, 2, 3)  # Then SAX
plt.plot(ts[0].ravel(), "b-", alpha=0.4)
plt.plot(sax_dataset_inv[0].ravel(), "b-")
plt.title("SAX, %d symbols" % n_sax_symbols)

plt.subplot(2, 2, 4)  # Finally, 1d-SAX
plt.plot(ts[0].ravel(), "b-", alpha=0.4)
plt.plot(one_d_sax_dataset_inv[0].ravel(), "b-")
plt.title("1d-SAX, %d symbols"
          "(%dx%d)" % (n_sax_symbols_avg * n_sax_symbols_slope,
                       n_sax_symbols_avg,
                       n_sax_symbols_slope))

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-224-691f19e48242> in <module>
#       2 n_paa_segments = 10
#       3 paa = PiecewiseAggregateApproximation(n_segments=n_paa_segments)
# ----> 4 ts_paa = paa.fit_transform(ts)
#       5 paa_dataset_inv = paa.inverse_transform(ts_paa)
#       6
#
# ~\Anaconda3\lib\site-packages\tslearn\piecewise.py in fit_transform(self, X, y, **fit_params)
#     196             PAA-Transformed dataset
#     197         """
# --> 198         X_ = to_time_series_dataset(X)
#     199         return self._fit(X_)._transform(X_)
#     200
#
# ~\Anaconda3\lib\site-packages\tslearn\utils.py in to_time_series_dataset(dataset, dtype)
#     185     if len(dataset) == 0:
#     186         return numpy.zeros((0, 0, 0))
# --> 187     if numpy.array(dataset[0]).ndim == 0:
#     188         dataset = [dataset]
#     189     n_ts = len(dataset)
#
# ...
